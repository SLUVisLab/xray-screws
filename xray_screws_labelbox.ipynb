# %%
import numpy as np
import cv2
import pandas as pd
import os
import labelbox
import json
import urllib.request

# %%
LB_API_KEY = '<YOUR_API_KEY>'
PROJECT_NUMBER = "clv2u76f5064n071jbjoab056"
TASK_ID = "clxax49ji0apv07xr6uhzhpq7" # Update task number based on labelbox export

OUTPUT_FILE_PATH = os.path.join(os.path.expanduser("~"), "Data/output/labelbox.json")
OUTPUT_IMAGE_DIR = os.path.join(os.path.expanduser("~"), "Data/output/cropped_images")
LABEL_DATA = os.path.join(os.path.expanduser("~"), "Data/manufacturers.csv")

client = labelbox.Client(api_key = LB_API_KEY)

export_task = labelbox.ExportTask.get_task(client, TASK_ID)

export_task.get_stream(converter=labelbox.FileConverter(file_path=OUTPUT_FILE_PATH)).start()

xray_count = 0

screw_count = 0

# Create log file, clear if exists
with open('errors.txt', 'w'):
    pass

def log_to_file(error_message):
    with open('errors.txt', 'a') as f:
        f.write(error_message + '\n')

# Retrieving the original images from labelbox storage requires only the provided
# image URL, no special headers. 
def get_image_noheaders(image_url):

  with urllib.request.urlopen(image_url) as url:
        s = url.read()
  # Convert the downloaded bytes to a numpy array
  arr = np.asarray(bytearray(s), dtype=np.uint8)
  # Decode the numpy array as an image
  img = cv2.imdecode(arr, -1)

  return img


# Retrieving the mask image requires inclusion of provided headers in request
def get_image_with_headers(url):
  req = urllib.request.Request(url, headers=client.headers)

  # Download the image, convert it to a NumPy array, and then read it into OpenCV format
  resp = urllib.request.urlopen(req)
  image = np.asarray(bytearray(resp.read()), dtype="uint8")
  image = cv2.imdecode(image, cv2.IMREAD_COLOR)
  
  return image


def find_manufacturer(accession_number):

  # Check that parameter is not empty
  if accession_number.strip():
    accession_number = accession_number.strip()

    df = pd.read_csv(LABEL_DATA)

    # Throw a more helpful error for column not found
    if 'Accession Number' not in df.columns:
      raise ValueError("'Accession Number' is not a column in the DataFrame.")

    row = df.loc[df['Accession Number'] == accession_number]

    if not row.empty:
        # Get the value from the 'Manufacturer' column
        manufacturer = row['Implant Manufacturer'].values[0] if not pd.isna(row['Implant Manufacturer'].values[0]) else "No manufacturer data"
    else:
        print("NO ACCESSION NUMBER MATCH")
        manufacturer = "No Accession Number Match"
  else:
    print("MISSING ACCESSION NUMBER")
    manufacturer = "Missing Accession Number"
        
  return manufacturer


def crop_to_mask(image_url, mask_url, mask_color):
  try:

    mask = get_image_with_headers(mask_url)
    image = get_image_noheaders(image_url)
    
    # reverse rgb to bgr for np
    bgr_color = mask_color[::-1]

    # Find the coordinates of the mask color pixels
    coords = np.where((mask == bgr_color).all(axis=2))

    # Find the minimum and maximum x and y values
    ymin, ymax = np.min(coords[0]), np.max(coords[0])
    xmin, xmax = np.min(coords[1]), np.max(coords[1])

    # Add padding to the bounding box
    padding = 20 
    xmin = max(0, xmin - padding)
    ymin = max(0, ymin - padding)
    xmax = min(mask.shape[1], xmax + padding)
    ymax = min(mask.shape[0], ymax + padding)

    # return the crop of the original image
    return image[ymin:ymax, xmin:xmax]


  except Exception as e:
    line_number = e.__traceback__.tb_lineno
    error_message = f"Error - Image Cropper: {e}, Image: {image_url}, Line: {line_number}"
    print(error_message)
    log_to_file(error_message)


def json_stream_handler(output):

  # Labelbox provides a composite mask image where each individual mask is a different color.
  # Get all of the RGB mask colors in a given image and loop through them to crop each individual mask out.

  try:

    data = json.loads(output.json_str)

    image_id = data['data_row']["global_key"]

    # For debuging problem images...
    # if image_id in ["117373809_00.jpg"]:
    #    print(data)

    accession_number = data["metadata_fields"][0]["value"]
    image_url = data["data_row"]["row_data"]  
    masks = data["projects"][PROJECT_NUMBER]["labels"][0]["annotations"]["objects"]
    mask_url = masks[0]["composite_mask"]["url"]
    mask_colors = [item["composite_mask"]["color_rgb"] for item in masks]
    # dataset_id = data["data_row"]["details"]["dataset_id"]
    # row_id = data["data_row"]["id"]

    # Make manufacturer directory if it doesnt exist
    manufacturer = find_manufacturer(accession_number)
    manufacturer_dir = os.path.join(OUTPUT_IMAGE_DIR, manufacturer)
    os.makedirs(manufacturer_dir, exist_ok=True)

    # Make accession number directory if it doesn't exist
    accession_dir = os.path.join(manufacturer_dir, accession_number)
    os.makedirs(accession_dir, exist_ok=True)
    
    for i, color in enumerate(mask_colors):
        
        # Strip the file extension from image_id and add a counter
        image_id_base = os.path.splitext(image_id)[0]
        image_id_new = f"{image_id_base}_{i}.jpg"
        # print(image_id_new)

        img_path = os.path.join(accession_dir, image_id_new)

        cropped_image = crop_to_mask(image_url, mask_url, color)

        cv2.imwrite(img_path, cropped_image)
        # print("Image saved...")
        global screw_count
        screw_count += 1
    
    # Logs
    global xray_count
    xray_count += 1
    print('**********************')
    print("Manufacturer: ", manufacturer)
    print("Accession Number: ", accession_number)
    print("xray count: ", xray_count)
    print("screw count: ", screw_count)

  except Exception as e:
    line_number = e.__traceback__.tb_lineno
    error_message = f"Error - Stream Handler: {e}, Image: {image_id}, Line: {line_number}"
    print(error_message)
    log_to_file(error_message)


# Stream the file to stdout
export_task.get_stream().start(stream_handler=json_stream_handler)
log_to_file("xray count: " + str(xray_count))
log_to_file("Screw count: " + str(screw_count))
print("stream handler finished")
# Out:
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  113292680
# xray count:  1
# screw count:  14
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115213728
# xray count:  2
# screw count:  18
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116788885
# xray count:  3
# screw count:  37
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114949278
# xray count:  4
# screw count:  39
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116788885
# xray count:  5
# screw count:  47
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115213728
# xray count:  6
# screw count:  55
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115213728
# xray count:  7
# screw count:  63
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116788885
# xray count:  8
# screw count:  69
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113581075
# xray count:  9
# screw count:  77
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114949278
# xray count:  10
# screw count:  79
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116741929
# xray count:  11
# screw count:  83
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114949278
# xray count:  12
# screw count:  87
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116741929
# xray count:  13
# screw count:  88
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116788885
# xray count:  14
# screw count:  100
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116741929
# xray count:  15
# screw count:  108
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116788885
# xray count:  16
# screw count:  113
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115213728
# xray count:  17
# screw count:  117
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113581075
# xray count:  18
# screw count:  120
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  117134345
# xray count:  19
# screw count:  135
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116077251
# xray count:  20
# screw count:  143
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116457066
# xray count:  21
# screw count:  147
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116457066
# xray count:  22
# screw count:  152
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116077251
# xray count:  23
# screw count:  156
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  3969254
# xray count:  24
# screw count:  161
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  117277863
# xray count:  25
# screw count:  165
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  117115093
# xray count:  26
# screw count:  177
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  117115093
# xray count:  27
# screw count:  181
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116338696
# xray count:  28
# screw count:  186
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116338696
# xray count:  29
# screw count:  192
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116338696
# xray count:  30
# screw count:  194
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113581075
# xray count:  31
# screw count:  198
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  117115093
# xray count:  32
# screw count:  203
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  113292680
# xray count:  33
# screw count:  212
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116338696
# xray count:  34
# screw count:  215
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115304998
# xray count:  35
# screw count:  227
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115304998
# xray count:  36
# screw count:  239
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114949278
# xray count:  37
# screw count:  243
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115304998
# xray count:  38
# screw count:  253
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  117373809
# xray count:  39
# screw count:  262
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  117373809
# xray count:  40
# screw count:  268
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114242758
# xray count:  41
# screw count:  272
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114242758
# xray count:  42
# screw count:  280
# Error - Image Cropper: zero-size array to reduction operation minimum which has no identity, Image: https://storage.labelbox.com/clg2m7dx5021r07061ukwbebf%2F8bcb3ab3-361c-4160-c95f-3ffaaa389ee9-00.jpg?Expires=1718227958839&KeyName=labelbox-assets-key-3&Signature=w1D9FaE7GFKqyLY4maKJkx2iLhE, Line: 93
# Error - Stream Handler: OpenCV(4.9.0) /Users/xperience/GHA-OpenCV-Python2/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
# , Image: 117373809_00.jpg, Line: 157
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  117134345
# xray count:  43
# screw count:  302
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115725428
# xray count:  44
# screw count:  314
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114019166
# xray count:  45
# screw count:  318
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115725428
# xray count:  46
# screw count:  326
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116975907
# xray count:  47
# screw count:  336
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114019166
# xray count:  48
# screw count:  344
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116741929
# xray count:  49
# screw count:  348
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116975907
# xray count:  50
# screw count:  362
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  3969726
# xray count:  51
# screw count:  372
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115237299
# xray count:  52
# screw count:  390
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  3969254
# xray count:  53
# screw count:  399
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  3969726
# xray count:  54
# screw count:  409
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  3969726
# xray count:  55
# screw count:  414
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115237299
# xray count:  56
# screw count:  422
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116352691
# xray count:  57
# screw count:  426
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  117082961
# xray count:  58
# screw count:  429
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116352691
# xray count:  59
# screw count:  437
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115183565
# xray count:  60
# screw count:  443
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  117082961
# xray count:  61
# screw count:  449
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116878388
# xray count:  62
# screw count:  455
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116878388
# xray count:  63
# screw count:  460
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114740757
# xray count:  64
# screw count:  467
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114568864
# xray count:  65
# screw count:  471
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114740757
# xray count:  66
# screw count:  475
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  113797571
# xray count:  67
# screw count:  478
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  4016161
# xray count:  68
# screw count:  492
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  113797571
# xray count:  69
# screw count:  497
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116457066
# xray count:  70
# screw count:  505
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  113797571
# xray count:  71
# screw count:  515
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  113797571
# xray count:  72
# screw count:  525
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  117277863
# xray count:  73
# screw count:  533
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114634343
# xray count:  74
# screw count:  541
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116667233
# xray count:  75
# screw count:  545
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116601677
# xray count:  76
# screw count:  552
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116667233
# xray count:  77
# screw count:  556
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116601677
# xray count:  78
# screw count:  561
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  117268317
# xray count:  79
# screw count:  571
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116601677
# xray count:  80
# screw count:  576
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114568864
# xray count:  81
# screw count:  586
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115304998
# xray count:  82
# screw count:  596
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  117268317
# xray count:  83
# screw count:  601
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115269638
# xray count:  84
# screw count:  609
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  117068627
# xray count:  85
# screw count:  617
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116352691
# xray count:  86
# screw count:  625
# NO ACCESSION NUMBER MATCH
# **********************
# Manufacturer:  No Accession Number Match
# Accession Number:  114339822
# xray count:  87
# screw count:  631
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115183565
# xray count:  88
# screw count:  637
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116387610
# xray count:  89
# screw count:  646
# NO ACCESSION NUMBER MATCH
# **********************
# Manufacturer:  No Accession Number Match
# Accession Number:  114339822
# xray count:  90
# screw count:  649
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116387610
# xray count:  91
# screw count:  658
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  115300834
# xray count:  92
# screw count:  663
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115913943
# xray count:  93
# screw count:  665
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116352691
# xray count:  94
# screw count:  669
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115780309
# xray count:  95
# screw count:  674
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  4016161
# xray count:  96
# screw count:  682
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  115300834
# xray count:  97
# screw count:  687
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  114037105
# xray count:  98
# screw count:  689
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  113609982
# xray count:  99
# screw count:  694
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114019166
# xray count:  100
# screw count:  698
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115780309
# xray count:  101
# screw count:  707
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  113609982
# xray count:  102
# screw count:  710
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113302241
# xray count:  103
# screw count:  712
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  113846513
# xray count:  104
# screw count:  716
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114634343
# xray count:  105
# screw count:  720
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113302241
# xray count:  106
# screw count:  724
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  114037105
# xray count:  107
# screw count:  732
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115183565
# xray count:  108
# screw count:  744
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  113846513
# xray count:  109
# screw count:  750
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116133611
# xray count:  110
# screw count:  754
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116133611
# xray count:  111
# screw count:  756
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116133611
# xray count:  112
# screw count:  758
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114705270
# xray count:  113
# screw count:  763
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  113846513
# xray count:  114
# screw count:  769
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  113846513
# xray count:  115
# screw count:  773
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  117411567
# xray count:  116
# screw count:  787
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  115300834
# xray count:  117
# screw count:  790
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115304097
# xray count:  118
# screw count:  798
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114705270
# xray count:  119
# screw count:  801
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115269638
# xray count:  120
# screw count:  805
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114705270
# xray count:  121
# screw count:  810
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  117411567
# xray count:  122
# screw count:  817
# NO ACCESSION NUMBER MATCH
# **********************
# Manufacturer:  No Accession Number Match
# Accession Number:  114088480
# xray count:  123
# screw count:  823
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114511748
# xray count:  124
# screw count:  825
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  117068627
# xray count:  125
# screw count:  829
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116765111
# xray count:  126
# screw count:  835
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114879990
# xray count:  127
# screw count:  839
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114511748
# xray count:  128
# screw count:  843
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  3977533
# xray count:  129
# screw count:  848
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114879990
# xray count:  130
# screw count:  850
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116083628
# xray count:  131
# screw count:  860
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114879990
# xray count:  132
# screw count:  862
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  114028351
# xray count:  133
# screw count:  864
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  114028351
# xray count:  134
# screw count:  868
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116667233
# xray count:  135
# screw count:  876
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116083628
# xray count:  136
# screw count:  881
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  3977533
# xray count:  137
# screw count:  891
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  114028351
# xray count:  138
# screw count:  893
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116317936
# xray count:  139
# screw count:  901
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116317936
# xray count:  140
# screw count:  907
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115349880
# xray count:  141
# screw count:  910
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115913943
# xray count:  142
# screw count:  914
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116765111
# xray count:  143
# screw count:  926
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116170167
# xray count:  144
# screw count:  929
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116514418
# xray count:  145
# screw count:  933
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115349880
# xray count:  146
# screw count:  943
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116170167
# xray count:  147
# screw count:  945
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116170167
# xray count:  148
# screw count:  948
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116514418
# xray count:  149
# screw count:  955
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113720301
# xray count:  150
# screw count:  958
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113720301
# xray count:  151
# screw count:  961
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116317936
# xray count:  152
# screw count:  967
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  116514418
# xray count:  153
# screw count:  975
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116170167
# xray count:  154
# screw count:  995
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114871761
# xray count:  155
# screw count:  1005
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114389190
# xray count:  156
# screw count:  1012
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114322642
# xray count:  157
# screw count:  1021
# Error - Image Cropper: HTTP Error 520: , Image: https://storage.labelbox.com/clg2m7dx5021r07061ukwbebf%2F63f52dc3-9e82-a876-acad-6ee7fe735040-01.jpg?Expires=1718227958931&KeyName=labelbox-assets-key-3&Signature=CHSdf4DlIN4Z7SWYKOnz0B_KaSE, Line: 83
# Error - Stream Handler: OpenCV(4.9.0) /Users/xperience/GHA-OpenCV-Python2/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
# , Image: 114322642_01.jpg, Line: 157
# NO ACCESSION NUMBER MATCH
# **********************
# Manufacturer:  No Accession Number Match
# Accession Number:  114088480
# xray count:  158
# screw count:  1026
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115485274
# xray count:  159
# screw count:  1031
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114389190
# xray count:  160
# screw count:  1035
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114871761
# xray count:  161
# screw count:  1040
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116788889
# xray count:  162
# screw count:  1048
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115349880
# xray count:  163
# screw count:  1056
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115349880
# xray count:  164
# screw count:  1061
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116924613
# xray count:  165
# screw count:  1064
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115304097
# xray count:  166
# screw count:  1068
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116788889
# xray count:  167
# screw count:  1075
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115485274
# xray count:  168
# screw count:  1078
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115673608
# xray count:  169
# screw count:  1082
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116924613
# xray count:  170
# screw count:  1088
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115673608
# xray count:  171
# screw count:  1092
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116317936
# xray count:  172
# screw count:  1096
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115485274
# xray count:  173
# screw count:  1097
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  117135857
# xray count:  174
# screw count:  1100
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116446748
# xray count:  175
# screw count:  1108
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114075826
# xray count:  176
# screw count:  1114
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115673608
# xray count:  177
# screw count:  1122
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116788889
# xray count:  178
# screw count:  1140
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114075826
# xray count:  179
# screw count:  1147
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116658208
# xray count:  180
# screw count:  1151
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116658208
# xray count:  181
# screw count:  1153
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116658208
# xray count:  182
# screw count:  1155
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  115954928
# xray count:  183
# screw count:  1176
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  115954928
# xray count:  184
# screw count:  1185
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116392459
# xray count:  185
# screw count:  1190
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  115954928
# xray count:  186
# screw count:  1198
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114075826
# xray count:  187
# screw count:  1203
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116392459
# xray count:  188
# screw count:  1211
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116446748
# xray count:  189
# screw count:  1219
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  117050436
# xray count:  190
# screw count:  1225
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114458194
# xray count:  191
# screw count:  1227
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  117050436
# xray count:  192
# screw count:  1233
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114458194
# xray count:  193
# screw count:  1237
# Error - Image Cropper: HTTP Error 524: , Image: https://storage.labelbox.com/clg2m7dx5021r07061ukwbebf%2Fc7a73e50-f25b-bf00-dadb-227c854a9c23-02.jpg?Expires=1718227958957&KeyName=labelbox-assets-key-3&Signature=qhhpcYO3Er4J5Yt4z-1L5S_At9c, Line: 83
# Error - Stream Handler: OpenCV(4.9.0) /Users/xperience/GHA-OpenCV-Python2/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
# , Image: 117246037_02.jpg, Line: 157
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  117246037
# xray count:  194
# screw count:  1260
# Error - Image Cropper: HTTP Error 520: , Image: https://storage.labelbox.com/clg2m7dx5021r07061ukwbebf%2Fba5c3f6f-7c9d-216a-bfe1-26ecc442bfb1-01.jpg?Expires=1718227958960&KeyName=labelbox-assets-key-3&Signature=qyxBldIpRJdzbYT6n00cQ_BCbP0, Line: 83
# Error - Stream Handler: OpenCV(4.9.0) /Users/xperience/GHA-OpenCV-Python2/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
# , Image: 116050737_01.jpg, Line: 157
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114048599
# xray count:  195
# screw count:  1270
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  117246037
# xray count:  196
# screw count:  1276
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114048599
# xray count:  197
# screw count:  1279
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115735425
# xray count:  198
# screw count:  1283
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115735425
# xray count:  199
# screw count:  1285
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116050737
# xray count:  200
# screw count:  1289
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116180262
# xray count:  201
# screw count:  1297
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116141150
# xray count:  202
# screw count:  1301
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114365005
# xray count:  203
# screw count:  1309
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114942777
# xray count:  204
# screw count:  1315
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  117174308
# xray count:  205
# screw count:  1328
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  117174308
# xray count:  206
# screw count:  1341
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114365005
# xray count:  207
# screw count:  1345
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  117174308
# xray count:  208
# screw count:  1357
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114942777
# xray count:  209
# screw count:  1366
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  117135857
# xray count:  210
# screw count:  1370
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  117174308
# xray count:  211
# screw count:  1382
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115695442
# xray count:  212
# screw count:  1386
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113789273
# xray count:  213
# screw count:  1395
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  117087287
# xray count:  214
# screw count:  1399
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  117087287
# xray count:  215
# screw count:  1401
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113789273
# xray count:  216
# screw count:  1410
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  114366832
# xray count:  217
# screw count:  1412
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  117135857
# xray count:  218
# screw count:  1420
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  114366832
# xray count:  219
# screw count:  1424
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  117050436
# xray count:  220
# screw count:  1436
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116924613
# xray count:  221
# screw count:  1442
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  4004892
# xray count:  222
# screw count:  1449
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  113562712
# xray count:  223
# screw count:  1461
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  4004892
# xray count:  224
# screw count:  1472
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115695442
# xray count:  225
# screw count:  1480
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  4004892
# xray count:  226
# screw count:  1500
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115726282
# xray count:  227
# screw count:  1506
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115726282
# xray count:  228
# screw count:  1511
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116180262
# xray count:  229
# screw count:  1515
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  115191230
# xray count:  230
# screw count:  1524
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116141150
# xray count:  231
# screw count:  1532
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  3954883
# xray count:  232
# screw count:  1544
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  115191230
# xray count:  233
# screw count:  1562
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116392459
# xray count:  234
# screw count:  1567
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115328120
# xray count:  235
# screw count:  1574
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  115191230
# xray count:  236
# screw count:  1591
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114653836
# xray count:  237
# screw count:  1595
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115032809
# xray count:  238
# screw count:  1614
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116944690
# xray count:  239
# screw count:  1628
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  3954883
# xray count:  240
# screw count:  1638
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116944690
# xray count:  241
# screw count:  1644
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115328120
# xray count:  242
# screw count:  1656
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114008942
# xray count:  243
# screw count:  1665
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115032809
# xray count:  244
# screw count:  1677
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116944690
# xray count:  245
# screw count:  1682
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115587904
# xray count:  246
# screw count:  1684
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  3952985
# xray count:  247
# screw count:  1686
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114008942
# xray count:  248
# screw count:  1690
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116946048
# xray count:  249
# screw count:  1704
# Error - Image Cropper: HTTP Error 520: , Image: https://storage.labelbox.com/clg2m7dx5021r07061ukwbebf%2Fb4802666-0344-f309-a2f4-99e21b757f12-00.jpg?Expires=1718227959002&KeyName=labelbox-assets-key-3&Signature=0Ba0F4bcZlcA3ULMLqQ2Gv5jaXo, Line: 83
# Error - Stream Handler: OpenCV(4.9.0) /Users/xperience/GHA-OpenCV-Python2/_work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp:786: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'
# , Image: 3952985_00.jpg, Line: 157
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114999073
# xray count:  250
# screw count:  1715
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115923116
# xray count:  251
# screw count:  1719
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114653836
# xray count:  252
# screw count:  1727
# **********************
# Manufacturer:  Seaspine mariner
# Accession Number:  115973006
# xray count:  253
# screw count:  1731
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115923116
# xray count:  254
# screw count:  1733
# **********************
# Manufacturer:  Seaspine mariner
# Accession Number:  115973006
# xray count:  255
# screw count:  1737
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  114212941
# xray count:  256
# screw count:  1755
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115450751
# xray count:  257
# screw count:  1758
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115450751
# xray count:  258
# screw count:  1765
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115998807
# xray count:  259
# screw count:  1769
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116452937
# xray count:  260
# screw count:  1777
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116452937
# xray count:  261
# screw count:  1780
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  114212941
# xray count:  262
# screw count:  1790
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  114255427
# xray count:  263
# screw count:  1798
# **********************
# Manufacturer:  Seaspine mariner
# Accession Number:  115973006
# xray count:  264
# screw count:  1806
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115998807
# xray count:  265
# screw count:  1808
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116414745
# xray count:  266
# screw count:  1812
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116946048
# xray count:  267
# screw count:  1826
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116414745
# xray count:  268
# screw count:  1832
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  116452937
# xray count:  269
# screw count:  1836
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116414745
# xray count:  270
# screw count:  1841
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115355607
# xray count:  271
# screw count:  1846
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116414745
# xray count:  272
# screw count:  1851
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115355607
# xray count:  273
# screw count:  1856
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114266257
# xray count:  274
# screw count:  1860
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114266257
# xray count:  275
# screw count:  1870
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  113760260
# xray count:  276
# screw count:  1877
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  114255427
# xray count:  277
# screw count:  1881
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114059577
# xray count:  278
# screw count:  1885
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114059577
# xray count:  279
# screw count:  1891
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116299495
# xray count:  280
# screw count:  1907
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115125674
# xray count:  281
# screw count:  1911
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  114424774
# xray count:  282
# screw count:  1919
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115690246
# xray count:  283
# screw count:  1927
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115355607
# xray count:  284
# screw count:  1937
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  114424774
# xray count:  285
# screw count:  1941
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  115587904
# xray count:  286
# screw count:  1945
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114529110
# xray count:  287
# screw count:  1948
# **********************
# Manufacturer:  seaspine mariner
# Accession Number:  114529110
# xray count:  288
# screw count:  1954
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  113562712
# xray count:  289
# screw count:  1966
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114266257
# xray count:  290
# screw count:  1976
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115690246
# xray count:  291
# screw count:  1980
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  115923116
# xray count:  292
# screw count:  1982
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114999073
# xray count:  293
# screw count:  1990
# **********************
# Manufacturer:  nuvasive reline
# Accession Number:  116299495
# xray count:  294
# screw count:  2006
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  115125674
# xray count:  295
# screw count:  2008
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  114266257
# xray count:  296
# screw count:  2013
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109158286
# xray count:  297
# screw count:  2015
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111531385
# xray count:  298
# screw count:  2024
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109158286
# xray count:  299
# screw count:  2034
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109158286
# xray count:  300
# screw count:  2040
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109158286
# xray count:  301
# screw count:  2041
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109158286
# xray count:  302
# screw count:  2059
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  112978882
# xray count:  303
# screw count:  2067
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  111788637
# xray count:  304
# screw count:  2077
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  111788637
# xray count:  305
# screw count:  2082
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111531385
# xray count:  306
# screw count:  2096
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111531385
# xray count:  307
# screw count:  2114
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109158286
# xray count:  308
# screw count:  2126
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111531385
# xray count:  309
# screw count:  2135
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109158286
# xray count:  310
# screw count:  2159
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  112978882
# xray count:  311
# screw count:  2163
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111151238
# xray count:  312
# screw count:  2173
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111151238
# xray count:  313
# screw count:  2189
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112365001
# xray count:  314
# screw count:  2216
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111151238
# xray count:  315
# screw count:  2227
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112365001
# xray count:  316
# screw count:  2236
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  4581460
# xray count:  317
# screw count:  2244
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  4581460
# xray count:  318
# screw count:  2248
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  110482817
# xray count:  319
# screw count:  2252
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  4581460
# xray count:  320
# screw count:  2260
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111157084
# xray count:  321
# screw count:  2265
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111157084
# xray count:  322
# screw count:  2275
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111514039
# xray count:  323
# screw count:  2293
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112365001
# xray count:  324
# screw count:  2303
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  111886001
# xray count:  325
# screw count:  2307
# NO ACCESSION NUMBER MATCH
# **********************
# Manufacturer:  No Accession Number Match
# Accession Number:  11875222
# xray count:  326
# screw count:  2316
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111539386
# xray count:  327
# screw count:  2325
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  111886001
# xray count:  328
# screw count:  2327
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112011215
# xray count:  329
# screw count:  2329
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  111886001
# xray count:  330
# screw count:  2331
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  110482817
# xray count:  331
# screw count:  2335
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112011215
# xray count:  332
# screw count:  2345
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109114246
# xray count:  333
# screw count:  2353
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109843208
# xray count:  334
# screw count:  2361
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112569420
# xray count:  335
# screw count:  2364
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109248549
# xray count:  336
# screw count:  2368
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109248549
# xray count:  337
# screw count:  2376
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112569420
# xray count:  338
# screw count:  2382
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  4561561
# xray count:  339
# screw count:  2390
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  4561561
# xray count:  340
# screw count:  2395
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109723396
# xray count:  341
# screw count:  2403
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109606533
# xray count:  342
# screw count:  2410
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109723396
# xray count:  343
# screw count:  2414
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  4561561
# xray count:  344
# screw count:  2419
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109606533
# xray count:  345
# screw count:  2433
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113027680
# xray count:  346
# screw count:  2443
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113027680
# xray count:  347
# screw count:  2448
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113027680
# xray count:  348
# screw count:  2453
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112042384
# xray count:  349
# screw count:  2456
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113027680
# xray count:  350
# screw count:  2466
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111155710
# xray count:  351
# screw count:  2474
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112042384
# xray count:  352
# screw count:  2480
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111288233
# xray count:  353
# screw count:  2485
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113027680
# xray count:  354
# screw count:  2490
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111288233
# xray count:  355
# screw count:  2500
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112063895
# xray count:  356
# screw count:  2512
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112063895
# xray count:  357
# screw count:  2532
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  110983741
# xray count:  358
# screw count:  2535
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112063895
# xray count:  359
# screw count:  2551
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  4551382
# xray count:  360
# screw count:  2557
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111155710
# xray count:  361
# screw count:  2561
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  4551382
# xray count:  362
# screw count:  2572
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  110983741
# xray count:  363
# screw count:  2578
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112914869
# xray count:  364
# screw count:  2591
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112914869
# xray count:  365
# screw count:  2608
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  110124034
# xray count:  366
# screw count:  2618
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112914869
# xray count:  367
# screw count:  2631
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112914869
# xray count:  368
# screw count:  2639
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  110124034
# xray count:  369
# screw count:  2659
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109213896
# xray count:  370
# screw count:  2673
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  109756947
# xray count:  371
# screw count:  2675
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  110859774
# xray count:  372
# screw count:  2681
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  109756947
# xray count:  373
# screw count:  2685
# **********************
# Manufacturer:  Orthofix firebird
# Accession Number:  113085832
# xray count:  374
# screw count:  2687
# **********************
# Manufacturer:  medtronic solera
# ...
# Accession Number:  111897082
# xray count:  420
# screw count:  3066
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111722365
# xray count:  421
# screw count:  3068
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111492195
# xray count:  422
# screw count:  3076
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  110180047
# xray count:  423
# screw count:  3084
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111492195
# xray count:  424
# screw count:  3092
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  108826698
# xray count:  425
# screw count:  3096
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111897082
# xray count:  426
# screw count:  3104
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  108826698
# xray count:  427
# screw count:  3108
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  108826698
# xray count:  428
# screw count:  3110
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  113028707
# xray count:  429
# screw count:  3121
# **********************
# Manufacturer:  Orthofix firebird
# Accession Number:  112427667
# xray count:  430
# screw count:  3124
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  113028707
# xray count:  431
# screw count:  3146
# **********************
# Manufacturer:  Orthofix firebird
# Accession Number:  112427667
# xray count:  432
# screw count:  3149
# **********************
# Manufacturer:  Orthofix firebird
# Accession Number:  112427667
# xray count:  433
# screw count:  3152
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  4551411
# xray count:  434
# screw count:  3155
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  4551411
# xray count:  435
# screw count:  3159
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  110428441
# xray count:  436
# screw count:  3160
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  110428441
# xray count:  437
# screw count:  3164
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  108982631
# xray count:  438
# screw count:  3175
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109751859
# xray count:  439
# screw count:  3178
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  108982631
# xray count:  440
# screw count:  3189
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113248391
# xray count:  441
# screw count:  3193
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  113248391
# xray count:  442
# screw count:  3201
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  108982631
# xray count:  443
# screw count:  3216
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109751859
# xray count:  444
# screw count:  3230
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  108982631
# xray count:  445
# screw count:  3249
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  110428441
# xray count:  446
# screw count:  3258
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112793746
# xray count:  447
# screw count:  3272
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  110075412
# xray count:  448
# screw count:  3278
# **********************
# Manufacturer:  Depuy expedium (Synthes)
# Accession Number:  110075412
# xray count:  449
# screw count:  3281
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112793746
# xray count:  450
# screw count:  3284
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112793746
# xray count:  451
# screw count:  3288
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109249189
# xray count:  452
# screw count:  3295
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109249189
# xray count:  453
# screw count:  3306
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109113927
# xray count:  454
# screw count:  3312
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112793746
# xray count:  455
# screw count:  3314
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109113927
# xray count:  456
# screw count:  3322
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111108381
# xray count:  457
# screw count:  3328
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111108381
# xray count:  458
# screw count:  3343
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109098234
# xray count:  459
# screw count:  3355
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111108381
# xray count:  460
# screw count:  3368
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109114216
# xray count:  461
# screw count:  3380
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109113927
# xray count:  462
# screw count:  3385
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  110162254
# xray count:  463
# screw count:  3392
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109114216
# xray count:  464
# screw count:  3403
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109970933
# xray count:  465
# screw count:  3407
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111108381
# xray count:  466
# screw count:  3413
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109970933
# xray count:  467
# screw count:  3416
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109970933
# xray count:  468
# screw count:  3424
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109970302
# xray count:  469
# screw count:  3432
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109970302
# xray count:  470
# screw count:  3448
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111968462
# xray count:  471
# screw count:  3457
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  113118311
# xray count:  472
# screw count:  3461
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  113118311
# xray count:  473
# screw count:  3465
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  112166691
# xray count:  474
# screw count:  3467
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109415488
# xray count:  475
# screw count:  3473
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111968462
# xray count:  476
# screw count:  3478
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109415488
# xray count:  477
# screw count:  3488
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  112166691
# xray count:  478
# screw count:  3492
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111968462
# xray count:  479
# screw count:  3497
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112509706
# xray count:  480
# screw count:  3503
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112509706
# xray count:  481
# screw count:  3506
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112509706
# xray count:  482
# screw count:  3511
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111242923
# xray count:  483
# screw count:  3514
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111968462
# xray count:  484
# screw count:  3517
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111242923
# xray count:  485
# screw count:  3525
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  112166691
# xray count:  486
# screw count:  3527
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111242923
# xray count:  487
# screw count:  3528
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  112611906
# xray count:  488
# screw count:  3533
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  112199688
# xray count:  489
# screw count:  3535
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111242923
# xray count:  490
# screw count:  3543
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  112611906
# xray count:  491
# screw count:  3550
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  111790905
# xray count:  492
# screw count:  3564
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  112199688
# xray count:  493
# screw count:  3566
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  111790905
# xray count:  494
# screw count:  3573
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  112611906
# xray count:  495
# screw count:  3583
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  112199688
# xray count:  496
# screw count:  3587
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  112582238
# xray count:  497
# screw count:  3595
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  112582238
# xray count:  498
# screw count:  3599
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  111807098
# xray count:  499
# screw count:  3616
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112798250
# xray count:  500
# screw count:  3621
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  112582238
# xray count:  501
# screw count:  3625
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112798250
# xray count:  502
# screw count:  3634
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  111807098
# xray count:  503
# screw count:  3645
# **********************
# Manufacturer:  rti
# Accession Number:  109412688
# xray count:  504
# screw count:  3653
# **********************
# Manufacturer:  rti
# Accession Number:  109412688
# xray count:  505
# screw count:  3659
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109750015
# xray count:  506
# screw count:  3667
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112500050
# xray count:  507
# screw count:  3685
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  110967330
# xray count:  508
# screw count:  3693
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109750015
# xray count:  509
# screw count:  3697
# **********************
# Manufacturer:  rti
# Accession Number:  109412688
# xray count:  510
# screw count:  3705
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112500050
# xray count:  511
# screw count:  3715
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  110967330
# xray count:  512
# screw count:  3719
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  110967330
# xray count:  513
# screw count:  3727
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  110967330
# xray count:  514
# screw count:  3731
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109303923
# xray count:  515
# screw count:  3737
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109303923
# xray count:  516
# screw count:  3749
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  110889994
# xray count:  517
# screw count:  3751
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  111516096
# xray count:  518
# screw count:  3764
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  111516096
# xray count:  519
# screw count:  3770
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  111516096
# xray count:  520
# screw count:  3774
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  110889994
# xray count:  521
# screw count:  3778
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  111516096
# xray count:  522
# screw count:  3787
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  111516096
# xray count:  523
# screw count:  3790
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  111122124
# xray count:  524
# screw count:  3794
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  111122124
# xray count:  525
# screw count:  3796
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  111122124
# xray count:  526
# screw count:  3798
# **********************
# Manufacturer:  rti
# Accession Number:  109036902
# xray count:  527
# screw count:  3804
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  111516096
# xray count:  528
# screw count:  3811
# **********************
# Manufacturer:  rti
# Accession Number:  109036902
# xray count:  529
# screw count:  3814
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  110285747
# xray count:  530
# screw count:  3824
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112907192
# xray count:  531
# screw count:  3832
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  112907192
# xray count:  532
# screw count:  3836
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  110285747
# xray count:  533
# screw count:  3841
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  110285747
# xray count:  534
# screw count:  3846
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111591036
# xray count:  535
# screw count:  3854
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109056018
# xray count:  536
# screw count:  3865
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  111591036
# xray count:  537
# screw count:  3876
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109244019
# xray count:  538
# screw count:  3878
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  109244019
# xray count:  539
# screw count:  3885
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109056018
# xray count:  540
# screw count:  3891
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  110436167
# xray count:  541
# screw count:  3897
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  110436167
# xray count:  542
# screw count:  3909
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109820236
# xray count:  543
# screw count:  3919
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  111940350
# xray count:  544
# screw count:  3922
# **********************
# Manufacturer:  orthofix firebird
# Accession Number:  111940350
# xray count:  545
# screw count:  3925
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  110545772
# xray count:  546
# screw count:  3931
# **********************
# Manufacturer:  Styker everest (K2M)
# Accession Number:  110545772
# xray count:  547
# screw count:  3934
# NO ACCESSION NUMBER MATCH
# **********************
# Manufacturer:  No Accession Number Match
# Accession Number:  11875222
# xray count:  548
# screw count:  3939
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109248549
# xray count:  549
# screw count:  3942
# **********************
# Manufacturer:  No manufacturer data
# Accession Number:  111807098
# xray count:  550
# screw count:  3951
# **********************
# Manufacturer:  medtronic solera
# Accession Number:  109820236
# xray count:  551
# screw count:  3957
# stream handler finished
