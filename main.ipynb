# %%
from scripts.convert_dicom import convert_dicom

print("done")
# Out:
# done

# %%
TOP_LEVEL_FOLDER = "thoracic_lumbar_1"

# Define input and output directories
input_dir = f"/lab/vislab/DATA/xray_screws/full_data/DICOM/{TOP_LEVEL_FOLDER}"
output_dir = f"/lab/vislab/DATA/xray_screws/full_data/IMAGE/{TOP_LEVEL_FOLDER}"

# Now run the function with these variables
convert_dicom(input_dir=input_dir, output_dir=output_dir)
# Out:
# 🚀 Starting DICOM to JPEG conversion with 4 threads...
# 📂 Found 491 DICOM files.
# 📂 Input Directory: /lab/vislab/DATA/xray_screws/full_data/DICOM/thoracic_lumbar_1
# 💾 Output Directory: /lab/vislab/DATA/xray_screws/full_data/IMAGE/thoracic_lumbar_1
# /student/acarnahan1/miniconda3/envs/screws_env/lib/python3.10/site-packages/pydicom/filereader.py:487: UserWarning: End of file reached before delimiter (FFFE,E0DD) found in file /lab/vislab/DATA/xray_screws/full_data/DICOM/thoracic_lumbar_1/115735425/RESULTS/Images/logo1.bmp
#   warn_and_log(msg, UserWarning)
# 100%|████████████████████████████████████████████████████████████████████████| 491/491 [00:01<00:00, 322.97it/s]
# ❌ Error processing /lab/vislab/DATA/xray_screws/full_data/DICOM/thoracic_lumbar_1/32897-368/4361/4365/4366: Unable to decompress 'JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])' pixel data because all plugins are missing dependencies:
# 	gdcm - requires gdcm>=3.0.10
# ...
